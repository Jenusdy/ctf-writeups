# %%
import pandas as pd

# %%
df = pd.read_csv('winchester77_signin_logs_2024.csv')
df.head()
# Out:
#            CreationTime        Operation  \
# 0  2024-01-01T08:20:33Z     UserLoggedIn
# 1  2024-01-01T10:15:30Z     UserLoggedIn
# 2  2024-01-01T11:33:47Z  UserLoginFailed
# 3  2024-01-01T14:23:02Z     UserLoggedIn
# 4  2024-01-01T15:56:19Z     UserLoggedIn
#
#                                           UserId ObjectId ResultStatus  \
# 0    george.wickham@winchester77.onmicrosoft.com    Login    Succeeded
# 1     mister.bennet@winchester77.onmicrosoft.com    Login    Succeeded
# 2  elizabeth.bennet@winchester77.onmicrosoft.com    Login       Failed
# 3       jane.bennet@winchester77.onmicrosoft.com    Login    Succeeded
# 4     mister.bennet@winchester77.onmicrosoft.com    Login    Succeeded
#
#           ClientIP                   AppId  \
# 0  228.187.229.214  Azure Active Directory
# 1   142.92.201.129  Azure Active Directory
# 2    35.236.112.95  Azure Active Directory
# 3       49.8.18.32  Azure Active Directory
# 4      88.52.75.72  Azure Active Directory
#
# ...

# %%
for i in df['UserId'].unique():
    df_temp = df.loc[(df['UserId'] == i) & (df['Operation'] == 'UserLoginFailed')]
    print(i, df_temp.shape[0])
# Out:
# george.wickham@winchester77.onmicrosoft.com 15
# mister.bennet@winchester77.onmicrosoft.com 364
# elizabeth.bennet@winchester77.onmicrosoft.com 20
# jane.bennet@winchester77.onmicrosoft.com 20
# fiztwilliam.darcy@winchester77.onmicrosoft.com 5
# catherine.debourgh@winchester77.onmicrosoft.com 6
# lydia.bennet@winchester77.onmicrosoft.com 24
# charles.bingley@winchester77.onmicrosoft.com 3

# %%
df.loc[(df['UserId'] == 'mister.bennet@winchester77.onmicrosoft.com') & (df['Operation'] == 'UserLoginFailed')].sort_values('CreationTime')
# Out:
#               CreationTime        Operation  \
# 92    2024-01-15T15:01:05Z  UserLoginFailed
# 718   2024-05-02T11:05:37Z  UserLoginFailed
# 720   2024-05-02T11:40:09Z  UserLoginFailed
# 722   2024-05-02T13:45:01Z  UserLoginFailed
# 723   2024-05-02T16:11:31Z  UserLoginFailed
# ...                    ...              ...
# 1928  2024-10-24T10:23:43Z  UserLoginFailed
# 1931  2024-10-24T12:20:00Z  UserLoginFailed
# 1933  2024-10-24T13:54:18Z  UserLoginFailed
# 1935  2024-10-24T15:18:10Z  UserLoginFailed
# 1938  2024-10-24T17:10:18Z  UserLoginFailed
#
#                                           UserId ObjectId ResultStatus  \
# 92    mister.bennet@winchester77.onmicrosoft.com    Login       Failed
# 718   mister.bennet@winchester77.onmicrosoft.com    Login       Failed
# 720   mister.bennet@winchester77.onmicrosoft.com    Login       Failed
# 722   mister.bennet@winchester77.onmicrosoft.com    Login       Failed
# 723   mister.bennet@winchester77.onmicrosoft.com    Login       Failed
# ...

# %%
Hero{2024-05-02;mister.bennet@winchester77.onmicrosoft.com}
